# %% [markdown]
# ### Step1: Importing Libraries

# %%
# Here, we used Libraries such as Pandas, Numpy, Matplotlib, Seaborn to analyse and estimate the Price of Diamonds based on the features.

import pandas as pd   # data processing, CSV file (e.g. pd.read_csv)
import numpy as np    # linear algebra
import seaborn as sns # 
import matplotlib.pyplot as plt

# %% [markdown]
# ---
#
# ### Step2: Read Dataset
# | Reading .CSV file from local directory |

# %%
H_data = pd.read_csv('housing.csv')

# %% [markdown]
# ---
#
# ### Step3: Exploration the Diamonds Dataset
# | 5 commands used for basic data exploration |
#
# - shape(): to check how many rows and columns in the dataset.
# - head(): to see a few sample rows of the data.
# - info() : to provides the summarized information of the data.
# - describe() : to show the descriptive statistical details of the numerical variables in this dataset.
# - nunique(): to helps us to identify if a column is categorical or continuous, so it used to get a acount of unique values.
#
# #### | Other commands |
# - columns(): to define the name of each column
# - dtypes(): to describe the type of the data (integer, float, Python object, etc.)
# - isnull(): to detect if there is any missing values in the dataset.

# %%
H_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2974 entries, 0 to 2973
# Data columns (total 25 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    2974 non-null   int64
#  1   city          2974 non-null   object
#  2   district      2974 non-null   object
#  3   front         2974 non-null   object
#  4   size          2974 non-null   int64
#  5   property_age  2974 non-null   int64
#  6   bedrooms      2974 non-null   int64
#  7   bathrooms     2974 non-null   int64
#  8   livingrooms   2974 non-null   int64
#  9   kitchen       2974 non-null   int64
#  10  garage        2974 non-null   int64
#  11  driver_room   2974 non-null   int64
#  12  maid_room     2974 non-null   int64
#  13  furnished     2974 non-null   int64
#  14  ac            2974 non-null   int64
#  15  roof          2974 non-null   int64
#  16  pool          2974 non-null   int64
#  17  frontyard     2974 non-null   int64
#  18  basement      2974 non-null   int64
#  19  duplex        2974 non-null   int64
#  20  stairs        2974 non-null   int64
#  21  elevator      2974 non-null   int64
#  22  fireplace     2974 non-null   int64
#  23  price         2974 non-null   int64
#  24  details       2912 non-null   object
# dtypes: int64(21), object(4)
# memory usage: 581.0+ KB

# %%
H_data.shape
# Out:
# (2974, 25)

# %%
H_data.columns
# Out:
# Index(['Unnamed: 0', 'city', 'district', 'front', 'size', 'property_age',
#        'bedrooms', 'bathrooms', 'livingrooms', 'kitchen', 'garage',
#        'driver_room', 'maid_room', 'furnished', 'ac', 'roof', 'pool',
#        'frontyard', 'basement', 'duplex', 'stairs', 'elevator', 'fireplace',
#        'price', 'details'],
#       dtype='object')

# %%
H_data.head(20)
# Out:
#     Unnamed: 0     city                 district      front  size  \
# 0          521   الرياض            حي الجنادرية         شرق   246
# 1         1653      جدة               حي بريمان        جنوب   350
# 2          131   الرياض               حي الرمال        جنوب   280
# 3         2284   الدمام      حي ضاحية الملك فهد        شمال   250
# 4           65   الرياض               حي الروضة        جنوب   352
# 5          175   الرياض               حي الروضة         شرق   900
# 6          158   الرياض               حي المصيف         غرب   500
# 7          993      جدة             حي البساتين         شرق   300
# 8         1922   الدمام               حي الشعلة         غرب   345
# 9         3217    الخبر     حي المدينة الرياضية   جنوب غربي   200
# 10        1553      جدة               حي الشاطئ        شمال   300
# 11        3707    الخبر         حي مدينة العمال   جنوب شرقي   348
# 12         979      جدة              حي الزهراء        جنوب   380
# 13        3399    الخبر              حي الصواري        شمال   312
# 14        2098   الدمام                حي السيف         غرب   300
# 15        2842    الخبر             حي الكورنيش        جنوب   300
# 16        2236   الدمام                 حي طيبة   شمال غربي   450
# 17        3115    الخبر              حي التحلية        جنوب   300
# 18        1162      جدة                حي الصفا   شمال غربي   892
# 19        3099    الخبر         حي مدينة العمال   جنوب شرقي   348
#
#     property_age  bedrooms  bathrooms  livingrooms  kitchen  ...  roof  pool  \
# 0              0         5          5            2        1  ...     0     0
# 1              0         7          5            2        1  ...     1     0
# 2              3         4          3            1        0  ...     0     0
# 3              5         5          5            3        1  ...     1     0
# 4             30         7          5            2        1  ...     1     0
# 5             15         4          4            2        1  ...     1     0
# 6             10         5          5            5        1  ...     1     0
# 7              7         3          4            3        1  ...     1     1
# 8              4         5          5            2        1  ...     0     0
# 9              7         5          4            1        1  ...     1     0
# 10             0         5          5            2        1  ...     1     1
# 11            30         5          5            3        1  ...     0     0
# 12             5         4          4            4        1  ...     1     0
# 13             0         5          5            3        0  ...     1     0
# 14            11         6          5            2        1  ...     1     0
# 15            13         6          5            2        1  ...     0     0
# 16             4         7          5            2        1  ...     1     0
# 17             0         5          5            3        1  ...     0     0
# 18            28         7          5            2        1  ...     1     0
# 19            30         5          5            3        1  ...     0     0
#
#     frontyard  basement  duplex  stairs  elevator  fireplace   price  \
# 0           0         0       0       1         0          0   40000
# 1           0         0       1       1         1          0   45000
# 2           1         0       0       1         0          1    3300
# 3           1         0       0       1         0          0   36000
# 4           1         0       0       1         0          1   80000
# 5           1         0       0       1         0          1  150000
# 6           1         1       0       1         1          0  150000
# 7           1         0       1       1         0          0  115000
# 8           1         0       1       0         0          0   60000
# 9           0         0       0       1         0          0   43000
# 10          1         0       1       1         0          0  250000
# 11          1         0       0       1         0          0   65000
# 12          1         0       1       1         0          1  185000
# 13          1         0       1       1         0          0   45000
# 14          1         0       1       1         0          0   75000
# 15          1         0       1       1         0          0   90000
# 16          1         0       0       1         0          1   55000
# 17          1         0       1       0         0          0   75000
# 18          1         0       0       1         0          0  170000
# 19          1         0       0       1         0          0   65000
#
#                                               details
# 0               درج داخلي للايجار التوالصل 0538143083
# 1   فلة روف مكونه من٩غرف و٧حمامات وسطح مرة كبير ون...
# 2   درج داخلي للأيجار  شهري3300\nالمواصفات \nالأرض...
# 3   للايجار فيلا دبلكس دورين وملحق في ضاحيه الملك ...
# 4   الجزء الثالث والاخير للتصوير\n================...
# 5   فيلا للايجار بحي الروضه \nمجلس وصاله ومقلط ومط...
# 6   فيلا بحي المصيف للايجار \nخمس اجنحة وقبو مجالس...
# 7   فيلا فاخرة للايجار  مؤثثة بالكامل حي البساتين ...
# 8   للايجار \nدبلكس منفصل في حي الرحاب الدمام\nمعل...
# 9   شقه دوبلكس تتكون من 2 طابق مدخل خاص \nبالراكه ...
# 10                                                NaN
# 11  فيلا زواية على شارعين ومرممه بالكامل \nقريبة م...
# 12  فيلا فاخرة مودرن مجهزة بالكامل  للايجار  الشاط...
# 13  فيلا للايجار في العزيزية \nالسعر ٤٥ألف ريال \n...
# 14  فلة في حي الراكة الشمالية متصلة للايجار تتكون ...
# 15  فيلا فاخرة في حي كورنيش الخبر. أفضل حي بالخبر....
# 16  للاجار بيت في حي طيبه زاويه\n\nمكون من \nالدور...
# 17  للايجار دوبلكس متصل بناء شخصي بحي التحلية بالخ...
# 18  مبني بمواصفات ارامكو بتكيف مركزي كرير وعوازل ل...
# 19  فيلا زواية على شارعين ومرممه بالكامل \nقريبة م...
#
# [20 rows x 25 columns]

# %%
# Summarize categorical features
H_data.describe(include=['object'])
# Out:
#           city                district front  \
# count     2974                    2974  2974
# unique       4                     167    10
# top      الخبر     حي ضاحية الملك فهد   شمال
# freq       778                     139   745
#
#                                                   details
# count                                                2912
# unique                                               1154
# top     مجمع ديار الروضة السكني يوفر لك جميع الخدمات و...
# freq                                                   49

# %%
sns.boxplot(H_data['price'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price'>

# %%
H_data[H_data.price <10000]
# Out:
#       Unnamed: 0     city                district      front  size  \
# 2            131   الرياض              حي الرمال        جنوب   280
# 162         1157      جدة              حي الزمرد        شمال   999
# 166         1255      جدة              حي الزمرد        جنوب   500
# 266          394   الرياض              حي الرمال         غرب   298
# 346         1971   الدمام     حي ضاحية الملك فهد         غرب   300
# 363         1100      جدة              حي الزمرد        شمال   350
# 434         1263      جدة              حي الشاطئ         غرب   350
# 603          787   الرياض                حي طويق   جنوب شرقي   200
# 668         1953   الدمام           حي المزروعية        شمال   365
# 676          257   الرياض              حي الرمال        شمال   270
# 710          490   الرياض              حي الرمال   جنوب شرقي   300
# 1279        1225      جدة              حي الشاطئ         غرب   350
# 1284        1202      جدة              حي الزمرد         شرق  1111
# 1675         917   الرياض              حي الرمال         شرق   370
# 1820         858   الرياض               حي ديراب        جنوب   312
# 2153         307   الرياض               حي الندى   شمال شرقي   270
# 2411        1192      جدة              حي الزمرد        جنوب   550
# 2518         801   الرياض              حي الرمال        شمال   390
# 2536         272   الرياض                حي طويق        شمال   260
#
#       property_age  bedrooms  bathrooms  livingrooms  kitchen  ...  roof  \
# 2                3         4          3            1        0  ...     0
# 162              0         3          2            1        1  ...     0
# 166              3         4          3            1        1  ...     0
# 266              0         4          4            1        1  ...     1
# 346              0         5          5            2        1  ...     1
# 363              0         4          4            1        1  ...     0
# 434              0         3          4            2        1  ...     1
# 603              2         5          5            1        1  ...     0
# 668              5         4          5            2        1  ...     0
# 676              3         4          4            1        1  ...     0
# 710              0         4          5            2        1  ...     1
# 1279             2         3          4            2        1  ...     1
# 1284             0         4          4            1        1  ...     0
# 1675             0         6          3            2        1  ...     0
# 1820            35         5          2            1        1  ...     0
# 2153             6         4          4            1        0  ...     0
# 2411             7         4          4            3        1  ...     1
# 2518             0         1          4            2        1  ...     0
# 2536             0         6          5            3        0  ...     1
#
#       pool  frontyard  basement  duplex  stairs  elevator  fireplace  price  \
# 2        0          1         0       0       1         0          1   3300
# 162      0          0         0       0       0         0          0   1100
# 166      1          1         1       1       1         0          0   2000
# 266      0          1         0       0       1         0          1   5000
# 346      0          1         0       1       1         0          0   1000
# 363      1          1         0       0       1         0          0   3000
# 434      1          1         0       0       1         0          0   3500
# 603      0          1         0       1       1         0          0   3000
# 668      0          0         0       1       0         0          0   7500
# 676      0          0         0       0       1         0          0   3200
# 710      0          1         0       0       1         0          0   4500
# 1279     1          1         0       1       1         0          0   2500
# 1284     1          1         0       1       1         0          1   1500
# 1675     0          1         0       0       1         0          0   3800
# 1820     0          0         0       0       1         0          0   2000
# 2153     0          0         0       0       1         0          0   6000
# 2411     1          1         0       1       0         0          1   2000
# 2518     0          0         0       0       1         0          1   4000
# 2536     0          1         0       0       1         0          1   5000
#
#                                                 details
# 2     درج داخلي للأيجار  شهري3300\nالمواصفات \nالأرض...
# 162   شالية في الحالمة دورة العروس\nالمواصفات :\nغرف...
# 166   شاليه كابري .. جزيرة الموج درة العروس \nاسعد ا...
# 266   فيلا للايجار قريبه من الخدمات فيها مكيفين الإج...
# 346   دوبلكس ٣٠٠م  للبيع مليون ريال \nحي الضاحيه الح...
# 363   فيلا دورين مكونة من 4 غرف نوم و 4 دورات مياه و...
# 434   فيلا الشاطئ جديده للايجار اليومي بالسعر المسجل...
# 603   فله لايجار درج صاله على شارعين مدخل سياره حوش ...
# 668   فيلا للإيجار بحي الشاطئ الغربي للتواصل على رقم...
# 676   اللايجار  درج داخلى بالرمال الذهبي    صغيره \n...
# 710   فيلا ايجار في الواحه علي شارعين\nمساحه ٣٠٠\nار...
# 1279  فيلا مؤثثه نظيفه جدا للايجار اليومي \nبالسعر ا...
# 1284  فيلا ف دوة العروس شاطى السعاده وسط الاسبوع ب15...
# 1675                                    الرمال السعيدان
# 1820           قريبه من المدرسة والايجار شهري دورين2000
# 2153                               اتاجرت اتاجرت اتاجرت
# 2411                   فيلا للايجار اليومي بخصوصية تامه
# 2518  فيلا للايجار في حي الرمال الوحه درج دخلي 2 شقه...
# 2536  فيلا جديدة فاخرة جداً ايجار شهري 5 الاف ريال ح...
#
# [19 rows x 25 columns]

# %%
H_data[H_data.price <10000].index
# Out:
# Int64Index([   2,  162,  166,  266,  346,  363,  434,  603,  668,  676,  710,
#             1279, 1284, 1675, 1820, 2153, 2411, 2518, 2536],
#            dtype='int64')

# %%
H_data.describe()
# Out:
#         Unnamed: 0         size  property_age     bedrooms    bathrooms  \
# count  2974.000000  2974.000000   2974.000000  2974.000000  2974.000000
# mean   1858.833557   366.525891      5.133490     5.087761     4.604573
# std    1075.717674   209.059809      7.664641     1.242549     0.701490
# min       0.000000     1.000000      0.000000     1.000000     1.000000
# 25%     930.250000   270.000000      0.000000     4.000000     4.000000
# 50%    1865.500000   330.000000      2.000000     5.000000     5.000000
# 75%    2789.750000   400.000000      8.000000     6.000000     5.000000
# max    3717.000000  5000.000000     36.000000     7.000000     5.000000
#
#        livingrooms      kitchen       garage  driver_room    maid_room  ...  \
# count  2974.000000  2974.000000  2974.000000  2974.000000  2974.000000  ...
# mean      2.238399     0.911231     0.799597     0.492939     0.792872  ...
# std       0.915901     0.284458     0.400370     0.500034     0.405317  ...
# min       1.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%       2.000000     1.000000     1.000000     0.000000     1.000000  ...
# 50%       2.000000     1.000000     1.000000     0.000000     1.000000  ...
# 75%       3.000000     1.000000     1.000000     1.000000     1.000000  ...
# max       5.000000     1.000000     1.000000     1.000000     1.000000  ...
#
#                 ac         roof         pool    frontyard     basement  \
# count  2974.000000  2974.000000  2974.000000  2974.000000  2974.000000
# mean      0.563551     0.519839     0.161399     0.803968     0.033961
# std       0.496028     0.499690     0.367960     0.397060     0.181159
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     1.000000     0.000000
# 50%       1.000000     1.000000     0.000000     1.000000     0.000000
# 75%       1.000000     1.000000     0.000000     1.000000     0.000000
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#             duplex       stairs     elevator    fireplace         price
# count  2974.000000  2974.000000  2974.000000  2974.000000  2.974000e+03
# mean      0.495965     0.816745     0.079018     0.184600  8.724988e+04
# std       0.500068     0.386940     0.269812     0.388038  7.230267e+04
# min       0.000000     0.000000     0.000000     0.000000  1.000000e+03
# 25%       0.000000     1.000000     0.000000     0.000000  5.225000e+04
# 50%       0.000000     1.000000     0.000000     0.000000  7.000000e+04
# 75%       1.000000     1.000000     0.000000     0.000000  1.000000e+05
# max       1.000000     1.000000     1.000000     1.000000  1.700000e+06
#
# [8 rows x 21 columns]

# %%
H_data.nunique()
# Out:
# Unnamed: 0      2974
# city               4
# district         167
# front             10
# size             181
# property_age      36
# bedrooms           7
# bathrooms          5
# livingrooms        5
# kitchen            2
# garage             2
# driver_room        2
# maid_room          2
# furnished          2
# ac                 2
# roof               2
# pool               2
# frontyard          2
# basement           2
# duplex             2
# stairs             2
# elevator           2
# fireplace          2
# price            101
# details         1154
# dtype: int64

# %% [markdown]
# #### Look for missing value

# %%
H_data.isnull().sum()
# Out:
# Unnamed: 0       0
# city             0
# district         0
# front            0
# size             0
# property_age     0
# bedrooms         0
# bathrooms        0
# livingrooms      0
# kitchen          0
# garage           0
# driver_room      0
# maid_room        0
# furnished        0
# ac               0
# roof             0
# pool             0
# frontyard        0
# basement         0
# duplex           0
# stairs           0
# elevator         0
# fireplace        0
# price            0
# details         62
# dtype: int64

# %%
H_data.dtypes
# Out:
# Unnamed: 0       int64
# city            object
# district        object
# front           object
# size             int64
# property_age     int64
# bedrooms         int64
# bathrooms        int64
# livingrooms      int64
# kitchen          int64
# garage           int64
# driver_room      int64
# maid_room        int64
# furnished        int64
# ac               int64
# roof             int64
# pool             int64
# frontyard        int64
# basement         int64
# duplex           int64
# stairs           int64
# elevator         int64
# fireplace        int64
# price            int64
# details         object
# dtype: object

# %%
sns.distplot(H_data['price']);
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Plotting histograms for various features
H_data.hist(bins=50, figsize=(17,10))
plt.show()
